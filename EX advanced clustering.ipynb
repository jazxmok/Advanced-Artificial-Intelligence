# %% [markdown]
# Import libraries

# %% [markdown]
# read and display the dataset

# %% [markdown]
# convert the data into number

# %% [markdown]
# assign new column to newly converted data

# %% [markdown]
# join the dataset

# %% [markdown]
# drop unnecessary column

# %% [markdown]
# print the dataset columns name

# %% [markdown]
# perform the clustering

# %% [markdown]
# plot the clustering results

# %% [markdown]
# combine the cluster result with the original dataframe

# %% [markdown]
# define each unique cluster

# %% [markdown]
# get the descriptive statistics for each cluster
